# %% [markdown]
# <a href="https://colab.research.google.com/github/esraa-abdelmaksoud/Shai-Assignment-Notebooks/blob/main/Seaborn_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Seaborn Exercises
#
# Time to practice your new seaborn skills! Try to recreate the plots below (don't worry about color schemes, just the plot itself.

# %% [markdown]
# ## The Data
#
# We will be working with a famous titanic data set for these exercises. Later on we will revisit this data. For now, we'll just focus on the visualization of the data with seaborn:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Exercises
#
# ** Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**
#
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
g = sns.JointGrid()
# plt.text(5,70,'pearsonr = 0.096; p=0.01', horizontalalignment='left')
# Negative values don't work. Please let me know how to get over this.
plt.annotate('pearsonr = 0.096; p=0.01', (0,70))    
x, y = titanic['fare'], titanic['age']
sc_ax = sns.scatterplot(x=x, y=y, ax=g.ax_joint, ec='None', alpha = 0.8, s=20,
                        color='steelblue')
sns.histplot(x=x, ax=g.ax_marg_x, bins=55, edgecolor='darkgray', alpha=0.3,
             color='steelblue')
sns.histplot(y=y, ax=g.ax_marg_y, edgecolor='darkgray', alpha=0.3,
             color='steelblue')
sc_ax.set(xlim=(-100,600))
# Out:
# [(-100.0, 600.0)]

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
# fig = sns.histplot(x=titanic['fare'], binwidth=17, color='r', alpha=0.4, edgecolor='gray')
fig = sns.distplot(x=titanic['fare'], color='r', kde=False, bins=30, hist_kws={'edgecolor':'gray'})
fig.set(xlim=(0,600), ylim=(0,500), xlabel='fare')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [(0.0, 500.0), (0.0, 600.0), Text(0.5, 0, 'fare')]

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
sns.boxplot(x=titanic['class'], y=titanic['age'], palette={'First':'deepskyblue','Second':'aquamarine','Third':'sandybrown'})

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
sns.swarmplot(x=titanic['class'], y=titanic['age'], data=titanic, hue="class", alpha=0.8, palette="Set2")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 15.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
# sns.countplot(titanic['sex'], palette={'male':'#4682B4','female':'#3CB371'})
sns.countplot(titanic['sex'], palette={'male':'steelblue','female':'mediumseagreen'}, alpha=0.9)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
df_corr = titanic.corr()
ax = sns.heatmap(df_corr, cmap='coolwarm', vmin=-0.9, vmax=0.9)
plt.title('titanic.corr()')
plt.xticks(rotation=0)
plt.show()

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
g = sns.FacetGrid(titanic, col="sex")
g.map_dataframe(sns.histplot, x='age', binwidth=8, edgecolor='dimgray', color='#4f85c2', alpha=1)
g.set(xlim=(0,80), ylim=(0,120), ylabel=None)

# %% [markdown]
# # Great Job!

# %% [markdown]
# ## #shAI Club
